# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# __Radim Jurca__
# <br>Data Scientist

# %% [markdown]
# _I enjoy continues learning and Data Science will never stop evolving. So here I am learning every day._

# %% [markdown]
# ### The following code will calculate multiplication and return all 8s

# %%
12345679*72
# Out:
# 888888888

# %% [markdown]
# __Numbered List:__
# 1. First item
# 1. Second item
# 1. Third item
# 1. Last item<br>
#
# __Table:__
#
# | Date | WorkDay | WorkHours |
# | --- | --- | --- |
# | 2022-07-31 | Sunday | 24|
#
# __Image:__
# ![pure-youth-crazy-english-cocker-260nw-1424153078.webp](attachment:pure-youth-crazy-english-cocker-260nw-1424153078.webp)
